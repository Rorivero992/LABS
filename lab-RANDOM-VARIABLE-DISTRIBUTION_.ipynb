# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("we_fn_use_c_marketing_customer_value_analysis.csv")

# %%
df_numerical=df.select_dtypes(include=np.number)
df_numerical
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
for col in df_numerical.columns:
    sns.displot(df_numerical[col])
    plt.title(col)
    plt.show()

# %%
def log_transfom_clean1(x):
    x = np.log(x)
    if np.isfinite(x):
        return x
    else:
        return 0
        
Customer_Lifetime_Value_log = list(map(log_transfom_clean1, df_numerical['Customer Lifetime Value']))
sns.distplot(Customer_Lifetime_Value_log)
plt.show()
# Out:
# C:\Users\roriv\AppData\Local\Temp\ipykernel_27548\527066663.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Customer_Lifetime_Value_log)
